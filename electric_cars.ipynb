# %% [markdown]
# <a href="https://colab.research.google.com/github/jimtoberfest/vol-view/blob/master/electric_cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mount

# %%
# from google.colab import drive
# # drive.mount('/drive')
# drive.mount("/drive", force_remount=True)
# Out:
# Mounted at /drive

# %% [markdown]
# #Imports

# %%
! pip install xlsxwriter -q

import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from time import sleep
from functools import reduce

# %% [markdown]
# #Scrape data

# %%
url = 'https://insideevs.com/reviews/344001/compare-evs/'


page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

dfs = pd.read_html(page.text)
print(len(dfs))
# Out:
# 5

# %%
# for i in range(len(dfs)):
#   print("\n\nTable,", i, ":")
#   print(dfs[i].head(2))

# %%
# select only dfs one wants a few of the tables are not valid info for this analysis

dfs_select = dfs[:-2]
len(dfs_select)
# Out:
# 3

# %%
def replace_headers_all_dfs(dfs):

  for i in range(len(dfs)):
    dfs[i].columns = dfs[i].loc[0]
    dfs[i] = dfs[i].loc[1:]
    dfs[i].reset_index(drop=True, inplace=True)

  return

# %%
replace_headers_all_dfs(dfs_select)
df_final = reduce(lambda left,right: pd.merge(left,right,on='Model', how='left'), dfs_select)
df_final.dropna(axis=1, how='all', inplace=True)
df_final.columns = df_final.columns.str.replace(r'_x$', '')
df_final.columns.str.strip()
# Out:
# Index(['Model', 'Base Price', 'Dest. Charge', 'Tax Credit', 'Effective Price',
#        'Drive', 'Battery(kWh)', 'EPARange', '0-60mph(sec)', 'TopSpeed'],
#       dtype='object', name=0)

# %%
df_final.head(2)
# Out:
# 0                           Model Base Price  ... 0-60mph(sec)           TopSpeed
# 0     2022 Audi e-tron GT quattro    $99,900  ...          3.9  152 mph(245 km/h)
# 1  2022 Audi RS e-tron GT quattro   $139,900  ...          3.1  155 mph(249 km/h)
#
# [2 rows x 10 columns]

# %%
df = df_final.copy()

# %% [markdown]
# #Data Wrangling

# %%
df['make'] = df['Model'].str.split(' ').str[1]
df['simple_model'] = (df['Model'].str.split(' ').str[2:])
df['simple_model'] = df['simple_model'].str.join(' ')
# type(df['Model'].str.split(' ').str[1])
df[df['make']=='Hyundai']
# Out:
# 0                                    Model  ...               simple_model
# 21       2022 Hyundai Ioniq 5 SE RWD (19")  ...       Ioniq 5 SE RWD (19")
# 22       2022 Hyundai Ioniq 5 SE AWD (19")  ...       Ioniq 5 SE AWD (19")
# 23  2022 Hyundai Ioniq 5 Limited AWD (20")  ...  Ioniq 5 Limited AWD (20")
# 24             2021 Hyundai IONIQ Electric  ...             IONIQ Electric
# 25              2022 Hyundai Kona Electric  ...              Kona Electric
#
# [5 rows x 12 columns]

# %%
df['Battery(kWh)'] = (df['Battery(kWh)'].str.replace('*',''))
df['Battery(kWh)'] = pd.to_numeric(df['Battery(kWh)'], errors='raise')
(df[df['make'] == 'Tesla' ])
# df.dtypes
# Out:
# 0                                     Model  ...                  simple_model
# 56   2021 Tesla Model 3 Standard Range Plus  ...   Model 3 Standard Range Plus
# 57        2021 Tesla Model 3 Long Range AWD  ...        Model 3 Long Range AWD
# 58      2021 Tesla Model 3 Perf. LR AWD 20"  ...      Model 3 Perf. LR AWD 20"
# 59  2021 Tesla Model S Long Range (AWD) 19"  ...  Model S Long Range (AWD) 19"
# 60             2021 Tesla Model S Plaid 19"  ...             Model S Plaid 19"
# 61             2021 Tesla Model S Plaid 21"  ...             Model S Plaid 21"
# 62  2021 Tesla Model X Long Range (AWD) 20"  ...  Model X Long Range (AWD) 20"
# 63             2021 Tesla Model X Plaid 20"  ...             Model X Plaid 20"
# 64    2021 Tesla Model Y Long Range AWD 19"  ...    Model Y Long Range AWD 19"
# 65      2021 Tesla Model Y Perf. LR AWD 21"  ...      Model Y Perf. LR AWD 21"
#
# [10 rows x 12 columns]

# %%
df[['EPARange_mi', 'EPARange_km']] = df['EPARange'].str.split('(', expand=True)

df['EPARange_mi'] = df['EPARange_mi'].str.split(' ').str[0]
df['EPARange_mi'] = pd.to_numeric(df['EPARange_mi'], errors='coerce').fillna(0).astype(int)

df['EPARange_km'] = df['EPARange_km'].str.split(' ').str[0]
df['EPARange_km'] = pd.to_numeric(df['EPARange_km'], errors='coerce').fillna(0).astype(int)


df[['EPARange_mi', 'EPARange_km']] = df['EPARange'].str.split('(', expand=True)



df.head(2)
# Out:
# 0                           Model Base Price  ... EPARange_mi EPARange_km
# 0     2022 Audi e-tron GT quattro    $99,900  ...     238 mi*     383 km)
# 1  2022 Audi RS e-tron GT quattro   $139,900  ...     232 mi*     373 km)
#
# [2 rows x 14 columns]

# %%
def split_units(df,new_cols, base_column, delimiter):
  
  df[new_cols] = df[base_column].str.split(delimiter, expand=True)

  df[new_cols[0]] = df[new_cols[0]].str.split(' ').str[0]
  df[new_cols[0]] = df[new_cols[0]].str.replace('*','')
  df[new_cols[0]] = pd.to_numeric(df[new_cols[0]], errors='coerce').fillna(0).astype(int)

  df[new_cols[1]] = df[new_cols[1]].str.split(' ').str[0]
  df[new_cols[1]] = df[new_cols[1]].str.replace('*','')
  df[new_cols[1]] = pd.to_numeric(df[new_cols[1]], errors='coerce').fillna(0).astype(int)

  return df

# %%
df_blue = df.copy()
df_blue = split_units(df_blue,['epa_mi', 'epa_km'], 'EPARange', '(' )
df_blue = split_units(df_blue,['top_speed_mi', 'top_speed_km'], 'TopSpeed', '(' )
df_blue
# Out:
# 0                                  Model Base Price  ... top_speed_mi top_speed_km
# 0            2022 Audi e-tron GT quattro    $99,900  ...          152          245
# 1         2022 Audi RS e-tron GT quattro   $139,900  ...          155          249
# 2                       2021 Audi e-tron    $65,900  ...          124          200
# 3             2021 Audi e-tron Sportback    $69,100  ...          124          200
# 4                 2022 Audi e-tron S 20"    $84,800  ...          130          209
# ..                                   ...        ...  ...          ...          ...
# 67              2022 Volvo XC40 Recharge    $55,300  ...          112          180
# 68        2021 Volkswagen ID.4 Pro (19")    $39,995  ...            0            0
# 69      2021 Volkswagen ID.4 Pro S (19")    $44,495  ...            0            0
# 70    2021 Volkswagen ID.4 AWD Pro (19")    $43,675  ...            0            0
# 71  2021 Volkswagen ID.4 AWD Pro S (19")    $48,175  ...            0            0
#
# [72 rows x 18 columns]

# %%
df = df_blue.copy()
df['Battery(kWh)'] = pd.to_numeric( df['Battery(kWh)'] ,errors='coerce').fillna(0).astype(int)
df['wh/mi'] = round((df['Battery(kWh)'] * 1000) / df['epa_mi']).fillna(0)
df.head()
len(df)
# Out:
# 72

# %%
df['Effective Price'] = df['Effective Price'].replace('[\$,]', '', regex=True).astype(float)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df['EPARange'].dropna(axis=0,how='any', inplace=True)
df['Tax Credit'].fillna(0, inplace=True)
df['Effective Price'] = pd.to_numeric(df['Effective Price'], errors='raise').fillna(0)
df['real_range'] = df['epa_mi'] *.7
len(df)
# Out:
# 72

# %%
df.sort_values('wh/mi', ascending=True)
# Out:
# 0                                       Model Base Price  ...  wh/mi real_range
# 30   2022 Lucid Air Dream Edition Range (19")   $169,000  ...  217.0      364.0
# 32         2022 Lucid Air Grand Touring (19")   $139,000  ...  217.0      361.2
# 24                2021 Hyundai IONIQ Electric    $33,245  ...  224.0      119.0
# 57          2021 Tesla Model 3 Long Range AWD    $49,990  ...  227.0      247.1
# 56     2021 Tesla Model 3 Standard Range Plus    $43,990  ...  229.0      183.4
# ..                                        ...        ...  ...    ...        ...
# 51    2021 Porsche Taycan Turbo Cross Turismo   $153,500  ...  456.0      142.8
# 4                      2022 Audi e-tron S 20"    $84,800  ...  457.0      145.6
# 52  2021 Porsche Taycan Turbo S Cross Turismo   $187,600  ...  460.0      141.4
# 48       2021 Porsche Taycan Turbo S (93 kWh)   $185,000  ...  463.0      140.7
# 20      2022 GMC Hummer EV Pickup (Edition 1)  $112,595*  ...  571.0      245.0
#
# [72 rows x 20 columns]

# %% [markdown]
# ##Simple Charts

# %%
df.plot.scatter(x='epa_mi', y='Effective Price')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig,ax = plt.subplots(figsize=(16,9))
sns.scatterplot(data=df,x='epa_mi',y='Effective Price', hue='make', style='make')

# %%
fig,ax = plt.subplots(figsize=(16,9))
sns.scatterplot(data=df,x='epa_mi',y='Effective Price', hue='make', style='make')
ax.set_xlim(200, 450)
ax.set_ylim(0, 75000)
# Out:
# (0.0, 75000.0)

# %%
# df = df[df['Effective Price'] < 77000]
df = df[df['Effective Price'] > 0]
df = df[df['epa_mi'] > 0]
df = df[df['real_range'] > 0]

# %%
import plotly.express as px

fig = px.scatter(df, x='epa_mi', y='Effective Price', color='make', hover_data=['simple_model'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c7765032-00bc-4c67-97e6-13da0dcf2ea5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c7765032-00bc-4c67-97e6-13da0dcf2ea5")) {
#                     Plotly.newPlot(
#                         'c7765032-00bc-4c67-97e6-13da0dcf2ea5',
#                         [{"customdata": [["e-tron GT quattro"], ["RS e-tron GT quattro"], ["e-tron"], ["e-tron Sportback"], ["e-tron S 20\""], ["e-tron S Sportback 20\""], ["Q4 40 e-tron (19\")"], ["Q4 50 e-tron quattro (19\")"], ["Q4 Sportback 50 e-tron quattro (20\")"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=Audi<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=Audi", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "make=Audi", "showlegend": true, "type": "scatter", "x": [238, 232, 222, 218, 208, 212, 250, 241, 241], "xaxis": "x", "y": [93445.0, 133445.0, 59495.0, 62695.0, 78395.0, 80995.0, 37495.0, 43495.0, 46295.0], "yaxis": "y"}, {"customdata": [["i3"], ["i3s"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=BMW<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=BMW", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "make=BMW", "showlegend": true, "type": "scatter", "x": [153, 153], "xaxis": "x", "y": [37945.0, 41145.0], "yaxis": "y"}, {"customdata": [["Bolt EV"], ["Bolt EUV"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=Chevrolet<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=Chevrolet", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "make=Chevrolet", "showlegend": true, "type": "scatter", "x": [259, 247], "xaxis": "x", "y": [31995.0, 33995.0], "yaxis": "y"}, {"customdata": [["Mustang Mach-E Select SR RWD"], ["Mustang Mach-E Select SR AWD"], ["Mustang Mach-E Route 1 ER RWD"], ["Mustang Mach-E Premium ER RWD"], ["Mustang Mach-E Premium ER AWD"], ["Mustang Mach-E GT ER AWD"], ["Mustang Mach-E GT Perf. ER AWD"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=Ford<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=Ford", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "make=Ford", "showlegend": true, "type": "scatter", "x": [230, 211, 305, 300, 270, 270, 260], "xaxis": "x", "y": [36495.0, 39195.0, 44000.0, 46200.0, 48900.0, 53500.0, 58500.0], "yaxis": "y"}, {"customdata": [["Hummer EV Pickup (Edition 1)"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=GMC<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=GMC", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "make=GMC", "showlegend": true, "type": "scatter", "x": [350], "xaxis": "x", "y": [112595.0], "yaxis": "y"}, {"customdata": [["IONIQ Electric"], ["Kona Electric"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=Hyundai<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=Hyundai", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "make=Hyundai", "showlegend": true, "type": "scatter", "x": [170, 258], "xaxis": "x", "y": [26750.0, 27685.0], "yaxis": "y"}, {"customdata": [["I-PACE EV400"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=Jaguar<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=Jaguar", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "make=Jaguar", "showlegend": true, "type": "scatter", "x": [234], "xaxis": "x", "y": [63550.0], "yaxis": "y"}, {"customdata": [["Niro EV (e-Niro)"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "make=Kia<br>epa_mi=%{x}<br>Effective Price=%{y}<br>simple_model=%{customdata[0]}", "legendgroup": "make=Kia", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "make=Kia", "showlegend": true, "type": "scatter", "x": [239], "xaxis": "x", "y": [33665.0], "yaxis": "y"}, {"customdata": [["Air Dream Edition Performance (19\")"], ["Air Dream Edition Performance (21\")"], ["Air Dream Edition Range (19\")"], ["Air  ...

# %%
# from sklearn.cluster import KMeans

# df_cluster = df.copy()



# kmeans = KMeans(n_clusters=5).fit(df_cluster[['epa_mi','Effective Price']])
# centroids = kmeans.cluster_centers_
# centroids

# %% [markdown]
# ## Top 10, subset

# %%
# Real Range 150+ and no RWD only models...TOP TEN CARS LEFT


df['$/mi_range'] = df['Effective Price'] / df['real_range']

df_top10 = df.copy()
df_top10 = df_top10.sort_values('$/mi_range')
df_top10 = df_top10[df_top10['real_range'] > 150]
df_top10 = df_top10[df_top10['Drive'] != 'RWD']
df_top10.head(10)
# Out:
# 0                                  Model Base Price  ... real_range  $/mi_range
# 25            2022 Hyundai Kona Electric    $34,000  ...      180.6  153.294574
# 39        2022 Nissan LEAF e+ S (62 kWh)    $32,400  ...      158.2  163.558786
# 11                2022 Chevrolet Bolt EV    $31,000  ...      181.3  176.475455
# 12               2022 Chevrolet Bolt EUV    $33,000  ...      172.9  196.616541
# 27             2022 Kia Niro EV (e-Niro)    $39,990  ...      167.3  201.225344
# 40       2022 Nissan LEAF e+ SV (62 kWh)    $37,400  ...      150.5  205.149502
# 57     2021 Tesla Model 3 Long Range AWD    $49,990  ...      247.1  207.163092
# 41      2022 Polestar 2 Single Motor 19"    $45,900  ...      185.5  214.016173
# 70    2021 Volkswagen ID.4 AWD Pro (19")    $43,675  ...      174.3  214.400459
# 71  2021 Volkswagen ID.4 AWD Pro S (19")    $48,175  ...      168.0  249.226190
#
# [10 rows x 21 columns]

# %%
df
# Out:
# 0                                  Model Base Price  ... real_range  $/mi_range
# 0            2022 Audi e-tron GT quattro    $99,900  ...      166.6  560.894358
# 1         2022 Audi RS e-tron GT quattro   $139,900  ...      162.4  821.705665
# 2                       2021 Audi e-tron    $65,900  ...      155.4  382.850708
# 3             2021 Audi e-tron Sportback    $69,100  ...      152.6  410.845347
# 4                 2022 Audi e-tron S 20"    $84,800  ...      145.6  538.427198
# ..                                   ...        ...  ...        ...         ...
# 67              2022 Volvo XC40 Recharge    $55,300  ...      156.1  313.228700
# 68        2021 Volkswagen ID.4 Pro (19")    $39,995  ...      182.0  185.109890
# 69      2021 Volkswagen ID.4 Pro S (19")    $44,495  ...      175.0  218.228571
# 70    2021 Volkswagen ID.4 AWD Pro (19")    $43,675  ...      174.3  214.400459
# 71  2021 Volkswagen ID.4 AWD Pro S (19")    $48,175  ...      168.0  249.226190
#
# [69 rows x 21 columns]

# %% [markdown]
# # Scrape Avg State Gasoline Price

# %%
# Set user agent to bypass 403 error on scraping
user_agent = "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.37"
url = url_gasoline
data = requests.get(url, headers={'User-Agent': user_agent})
code = BeautifulSoup(data.text, 'html.parser')

url_gasoline = 'https://gasprices.aaa.com/?state=TX'
url=url_gasoline

# Make a GET request to fetch the raw HTML content
page = requests.get(url).text
page = requests.get(url, headers={'User-Agent': user_agent}).text

# # Parse the html content
soup = BeautifulSoup(page, "lxml")

# All tables to list
dfs_gasoline_all = pd.read_html(page)
# print(len(dfs_gasoline))

# Grab first table, first gas price needed
df_gasoline = dfs_gasoline[0]
gas_price = float(df_gasolina['Regular'][0].replace('$',''))
gas_price
# Out:
# 3.034

# %%
# import xlsxwriter

# file_path = '/content/drive/MyDrive/electric_cars/'
# file_name = 'electric_cars_data.xlsx'

# writer = pd.ExcelWriter('/drive/My Drive/eCars_V1.xlsx', engine='xlsxwriter')

# df.to_excel(writer, sheet_name='raw_data_modified')

# df_top10.to_excel(writer, sheet_name='Top_10')

# # #df3.to_excel(writer, sheet_name='Sheetc')

# writer.save()
# df.to_csv('/drive/My Drive/eCars.csv')

# %% [markdown]
# # SET ASSUMPTIONS:  Costs to charge

# %%
residential_per_kWh = .14
supercharger_per_kWh = .28  # avg of researched prices:  https://www.myev.com/research/ev-101/what-it-costs-to-charge-an-electric-vehicle

L2_home_charger = 2000.0
mean_mi_per_year = 12000
amortorized_L2_charger_period_yrs = 3

avg_mpg = 25

# %% [markdown]
# ## costs to table

# %%
df['home_charge_cost_batt'] = df['Battery(kWh)'] *  residential_per_kWh
df['home_cost_real_mi'] = df['home_charge_cost_batt'] / df['real_range']
df['L2_home_cost_real_mi'] = ((L2_home_charger / mean_mi_per_year) / amortorized_L2_charger_period_yrs) + df['home_cost_real_mi']

df['supercharger_cost_batt'] = df['Battery(kWh)'] *  supercharger_per_kWh
df['supercharger_cost_real_mi'] = df['supercharger_cost_batt'] / df['real_range']

# df[df['make'] == 'Tesla']

df['gas_car_per_mi_cost'] = gas_price / avg_mpg

# %%
df['L2_home_vs_gas'] = df['L2_home_cost_real_mi'] - df['gas_car_per_mi_cost']

# %%
df[df['make'] == 'Tesla']

# df[df['simple_model'] == '2021 Tesla Model X Long Range (AWD) 20"']

df.loc[57]
# Out:
# 0
# Model                        2021 Tesla Model 3 Long Range AWD
# Base Price                                             $49,990
# Dest. Charge                                           +$1,200
# Tax Credit                                                   0
# Effective Price                                          51190
# Drive                                                      AWD
# Battery(kWh)                                                80
# EPARange                                        353 mi(568 km)
# 0-60mph(sec)                                               4.2
# TopSpeed                                     145 mph(233 km/h)
# make                                                     Tesla
# simple_model                            Model 3 Long Range AWD
# EPARange_mi                                             353 mi
# EPARange_km                                            568 km)
# epa_mi                                                     353
# epa_km                                                     568
# top_speed_mi                                               145
# top_speed_km                                               233
# wh/mi                                                      227
# real_range                                               247.1
# $/mi_range                                             207.163
# home_charge_cost_batt                                     11.2
# home_cost_real_mi                                    0.0453258
# L2_home_cost_real_mi                                  0.100881
# supercharger_cost_batt                                    22.4
# supercharger_cost_real_mi                            0.0906516
# gas_car_per_mi_cost                                    0.12136
# L2_home_vs_gas                                      -0.0204787
# Name: 57, dtype: object

# %%
df_top10 = df.copy()
df_top10 = df_top10.sort_values('$/mi_range')
df_top10 = df_top10[df_top10['real_range'] > 150]
df_top10 = df_top10[df_top10['Drive'] != 'RWD']
# df_top10.head(10)

# %% [markdown]
# #Save to CSV

# %%
# df.to_csv('/drive/My Drive/eCars.csv')


# import xlsxwriter

# file_path = '/content/drive/MyDrive/electric_cars/'
# file_name = 'electric_cars_data.xlsx'

# writer = pd.ExcelWriter('/drive/My Drive/eCars_V1.xlsx', engine='xlsxwriter')

# df.to_excel(writer, sheet_name='raw_data_modified')

# df_top10.to_excel(writer, sheet_name='Top_10')

# # #df3.to_excel(writer, sheet_name='Sheetc')

# writer.save()
